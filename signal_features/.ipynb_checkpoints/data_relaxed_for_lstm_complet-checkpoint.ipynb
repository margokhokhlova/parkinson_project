# %%
from scipy import io as sio
from matplotlib import pyplot as plt
import numpy as np
import random

# %% [markdown]
# ## Блокнот, чтобы собрать все нужные данные для LSTM
#
# ### Расширенный список  характеристик, с добавлением характеристик, не использующихся в патенте.

# %% [markdown]
# Previously, we discovered that the following characteristics of wave trains are beneficial for identifying various neurodegenerative diseases:
# * Frequency
# * Duration Periods
# * Bandwith
#
# What is important is that these characteristics do not depend on the equipment used to record the EMG, making them theoretically applicable to any hardware setup. Our experiments have demonstrated the effectiveness of the wave-train method (citation here). However, the simplified version of the method has shown a slight decrease in performance on the current dataset.
#
# Other research studies (cite Thai paper) have shown that temporal characteristics of tremor can aid in distinguishing Parkinson's disease (PD) from essential tremor (ET), with excellent results reported. We tested their method on our data and found that the proposed method can indeed assist in classifying PD from ET, and even PD from the Control group. However, the accuracy we obtained is significantly lower than that reported in the (cite Thai paper).
#
# In this reasearch we pursue our quete to find a method for early stage diagnostics of neurogenerative diseases, and we want to combine wave-trains from (cite paper) with their temporal aspects. For the latter  we experiment with various sequence models, which can learn to  capture temporal dependences.
#
# In order to compare the role of temporal information, we collect different features of wave-trains and time information.

# %% [markdown]
# Из патента следуюет, что используются 3 признака:
# * Центральная частота -Freq
# * Длительность на полувысоте - DuratPeriods
# * Ширина полосы частот на полувысоте - BandwidthesHz
#
# Также важен четвертый параметр, время, чтобы расположить всплески по очередности:
# * Time - время между последовательноми всплесками
#
# Для полного листа характеристик, нам нужно еще добавить:
# * Ampl
# * DuratSeconds
# * Frac_Band
# * Phase

# %% [markdown]
# Начнем с одной группой пациентов, соберем все соотвествующие фамилии,совпадающие с названиями файлов.

# %%
from os import listdir
from os.path import isfile, join
data_path = 'C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl/'
patients = set()
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]
# filter the files by name
for f in onlyfiles:
    if f[-3:]=='txt':
        pat = f.split('_')[0]
        patients.add(pat)
print(f'Пациенты из группы {data_path.split("/")[-2]}: {patients}')
# Out:
# Пациенты из группы Margo_DATA_Control_rassl: {'Хвал0207.txt', 'Сидо0205.txt', 'Лега0204.txt', 'Черк0208.txt', 'Аста0201.txt', 'Фрол0206.txt', 'Керш0203.txt', 'Дюки0202.txt'}

# %%
# вспомогательная функция чтобы загрузить все параметры, которые нас интерусуют, из формата матлаб
def load_parameter(patient, EMG, parameter, data_path = 'C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl/'):
    print(data_path +'/'+patient + '_EMG' + str(EMG)+ parameter + '.mat')
    mat_contents = sio.loadmat(data_path +'/'+patient + '_EMG' + str(EMG)+ parameter + '.mat')
    if parameter =='BandwidthesHz':
        signal  = mat_contents['Flash_Band_In_Hz_Stack']
    elif parameter == 'DuratPeriods':
        signal = mat_contents['Flash_Durat_In_Periods_Stack']
    elif parameter == 'Freq':
        signal  = mat_contents['Flash_Freq_Stack']
    elif parameter == 'Time':
         signal = mat_contents['Flash_Time_Stack']
    elif parameter == 'Ampl':
        signal = mat_contents['Flash_Ampl_Stack']
    elif parameter == 'DuratSeconds':
        signal = mat_contents['Flash_Durat_In_Seconds_Stack']
    elif parameter == 'Frac_Band':
        signal = mat_contents['Flash_Frac_Band_Stack']
    elif parameter == 'Phase':
        signal = mat_contents['Flash_Phase_Stack']
    else:
        print('no parameter, but the keys are', sorted(mat_contents.keys()))
    return signal

# %% [markdown]
# Мы берем лишь одну руку у пациентов на данном этапе,  у правых - правую, у левых - левую, а у ЭТ - можно любую, у контроля - тоже любую.
#
# * EMG1 - левая рука
#
# *
# EMG2 - правая рука
# *
# EMG3 - левая ног
# * а
# EMG4 - правая нога
#
# The number of detected wave trains varies between different data sequences and even among different limbs of a patient. It is common in research studies to place sensors on the patient's hand. Thus, for the initial set of experiments, we have chosen to focus on the hand as the sensor placement location.
#
# For patients with Parkinson's disease (PD) exhibiting tremor in the right hand, we analyze the data from the right hand. Similarly, for PD patients with tremor in the left hand, we analyze the data from the left hand. For control subjects and essential tremor (ET) patients, data from either hand can be used, but we have selected the right hand for consistency.

# %%
# вспомогательная функция, чтобы загрузить все выбранные сигналы, а также время каждого сигнала
def extract_wavetrains(patients, data_path, emg):
    for n, patient in enumerate(patients):
        # у нас 4 сигнала EMG, но мы берем лишь 1, правую или левую руку, emg 2 / emg 1 соответственно

        freq_signal = load_parameter(patient,emg,'Freq',data_path)
        Flash_Durat_signal = load_parameter(patient,emg,'DuratPeriods',data_path)
        BandwidthesHz_signal = load_parameter(patient,emg,'BandwidthesHz',data_path)
        TimeSignal = load_parameter(patient,emg,'Time',data_path)
        Ampl = load_parameter(patient, emg, 'Ampl',data_path)
        DuratSeconds =  load_parameter(patient, emg, 'DuratSeconds', data_path)
        Frac_Band =  load_parameter(patient, emg, 'Frac_Band', data_path)
        Phase =  load_parameter(patient, emg, 'Phase', data_path)
        
            
        # достать время для этих сигналов -- пока не изпользуется, возможно для нормализации
        mat_contents = sio.loadmat(data_path + patient + '_EMG'+str(emg)+'TimeAndFrequency.mat')
        time_signal  = mat_contents['Time']
        total_sec = max(time_signal.ravel())-min(time_signal.ravel())
        
        # sort all signals by time (in the order of recording)
        time_order = sorted(range(len(TimeSignal)), key=lambda k: TimeSignal[k])
        features = (freq_signal,Flash_Durat_signal,BandwidthesHz_signal,TimeSignal,time_order, total_sec, Ampl, DuratSeconds,Frac_Band,Phase)
    return features

# %% [markdown]
# Теперь осталось только сортировать наши всплески по пере их появления, и добавить переменную времени. Следующая функция про это.

# %%
def sort_by_time(features):
    '''time is always last in the order of features'''
    freq_signal,Flash_Durat_signal,BandwidthesHz_signal,TimeSignal,time_order, total_sec, Ampl, DuratSeconds,Frac_Band, Phase = features
    freq_signal_ordered = [freq_signal[i][0] for i in time_order]
    Flash_Durat_signal_ordered = [Flash_Durat_signal[i][0] for i in time_order]
    BandwidthesHz_signal_ordered = [BandwidthesHz_signal[i][0] for i in time_order]
    timeSignal_ordered =  [TimeSignal[i][0] for i in time_order]
    Ampl_ordered = [Ampl[i][0] for i in time_order]
    DuratSeconds_ordered = [DuratSeconds[i][0] for i in time_order]
    Frac_Band_ordered = [Frac_Band[i][0] for i in time_order]
    Phase_ordered = [Phase[i][0] for i in time_order]
    # get time  features for LSTM model in the shape of time between two сonsecutive wavetrains
    t1 = [0]+timeSignal_ordered
    t2 = timeSignal_ordered + [0]
    timeSignal_for_lstm = [a_i - b_i for a_i, b_i in zip(t2, t1)]
    feat_dictionary = {'freq':freq_signal_ordered, 'flash':Flash_Durat_signal_ordered, 'bandwidth':BandwidthesHz_signal_ordered,
                       'timeSignal':timeSignal_ordered, 'time_sincelast':timeSignal_for_lstm, "ampl":Ampl_ordered,
                        'duratSec':DuratSeconds_ordered, 'frac':Frac_Band_ordered, 'phase':Phase_ordered }
    return feat_dictionary

# %% [markdown]
# Теперь попробуем извлечь и построить характеристики для одного из пациентов, выбранного случайным образом из контрольной группы.

# %%
patient = random.sample(patients, 1)
patient
# Out:
# ['Лега0204.txt']

# %%
features = extract_wavetrains(patient, data_path, 1)
# check all files where we can information, so that it corresponds to this patient
# Out:
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Лега0204.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Лега0204.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Лега0204.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Лега0204.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Лега0204.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Лега0204.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Лега0204.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Лега0204.txt_EMG1Phase.mat

# %%
sorted_features = sort_by_time(features)

# %% [markdown]
# В настоящий момент, планируется использовать время от последнего всплеска как одну из характеристик для входа в LSTM.

# %%
plt.figure(figsize=(12,3))
plt.plot(sorted_features['time_sincelast'][:-1], '-o')
plt.title('Time since last wavetrain')
# Out:
# Text(0.5, 1.0, 'Time since last wavetrain')

# %% [markdown]
# timeSignal_ordered
# #print(timeSignal_ordered.insert(0,0))

# %%
plt.plot(sorted_features['timeSignal'][:300], sorted_features['freq'][:300], 'r-*')
plt.title("Frequency vs time")
plt.xlabel('time, sec', fontweight='bold')
plt.ylabel('Frequency', fontweight='bold')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.plot(sorted_features['timeSignal'][:300], sorted_features['flash'][:300], 'b-*')
plt.title("Flash duration vs time")
plt.xlabel('time, sec', fontweight='bold')
plt.ylabel('Flash duration', fontweight='bold')
# Out:
# Text(0, 0.5, 'Flash duration')

# %%
plt.plot(sorted_features['timeSignal'][:300], sorted_features['bandwidth'][:300], 'g-*')
plt.title("Bandwidth vs time")
plt.xlabel('time, sec', fontweight='bold')
plt.ylabel('Bandwidth', fontweight='bold')
# Out:
# Text(0, 0.5, 'Bandwidth')

# %%
plt.plot(sorted_features['timeSignal'][:300], sorted_features["ampl"][:300], 'y-*')
plt.title("Amplitude vs time")
plt.xlabel('time, sec', fontweight='bold')
plt.ylabel('Ampl', fontweight='bold')
# Out:
# Text(0, 0.5, 'Ampl')

# %%
plt.plot(sorted_features['timeSignal'][:300], sorted_features["phase"][:300], 'm-*')
plt.title("Phase vs time")
plt.xlabel('time, sec', fontweight='bold')
plt.ylabel('Phase', fontweight='bold')
# Out:
# Text(0, 0.5, 'Phase')

# %%
plt.figure(figsize=(12,3))
plt.plot(sorted_features['timeSignal'], sorted_features['bandwidth'], 'g--')
plt.plot(sorted_features['timeSignal'], sorted_features['flash'], 'b--')
plt.plot(sorted_features['timeSignal'], sorted_features['freq'], 'r--')
plt.plot(sorted_features['timeSignal'], sorted_features["ampl"], 'y-*')
plt.plot(sorted_features['timeSignal'], sorted_features["phase"], 'm--')


plt.title("All key parameters vs time all sequence")
plt.xlabel('time, sec', fontweight='bold')
plt.ylabel('Bandwidth, Flash Dur, Freq', fontweight='bold')
# Out:
# Text(0, 0.5, 'Bandwidth, Flash Dur, Freq')

# %% [markdown]
# Проверка времени между всплесками с помощью построенной диаграммы.

# %%
plt.hist(time_lstm,bins=100, range=(0,1))
plt.title("Histogram of the time between wavetrains")
# Out:
# Text(0.5, 1.0, 'Histogram of the time between wavetrains')

# %%
len(time_s)
# Out:
# 1266

# %% [markdown]
# ## Выводы
# Все данные разной длины (разное кол-во всплесков),  и разной размерности,  и в разном диапазоне значений. так что их необходимо будет нормализовывать.
# В то же время, данные более-менее равномерны в течении всей последовательности записи у контрольной группы.
# На данном этапе, мы предлагаем брать отрезки по 80 всплесков, с небольшими повторениями (порядка 10 всплесков), и на этих отрезка пробовать классифицировать данные.
# В дальнейшем, можно попробоать различные сценарии, например, с предсказаниями следующего всплекска.
# Не совсем понятно, что лучше делать со временем, пока самое просто будет закодировать время всплеска в диапазоне 0-1.
#
#
# As the plots demonstrate, the different characteristics of wave trains fall within different ranges of values, necessitating their normalization prior to inputting them into the LSTM model. Furthermore, the length of a sequence of wave trains varies among patients, a challenge we will address in a later stage by employing a sliding window approach.
#
# The timing of wave train occurrences serves as an important parameter, enabling the capture of various relational information within our data. However, drawing an analogy with text models (cite), preprocessing of time is required before utilizing it as a feature in the input of a deep learning model. Other researchers have employed various methods for encoding time (provide a list of methods). In our initial baseline, we plan to utilize the time between consecutive wave trains, measured in seconds.

# %% [markdown]
# Далее мы подготавливаем данные для LSTM, сохраняя их, но пока не разделяя их на отдельные тест сеты. Все эти эксперименты могут быть сделаны дальше, во время работы с алгоритмом классификации данных.

# %% [markdown]
# #### Данные для контроля

# %%
import csv
strFileName = 'C:/Users/khokhlovam/Documents/kotelnikov/data/data_lstm_test_complet.csv'

# %% [markdown]
# Про данные:
# data_lstm_test1.csv - исходная длина файлов.

# %%
data_path = 'C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl/'
patients = set()
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]
# filter the files by name
for f in onlyfiles:
    if f[-3:]=='txt':
        pat = f.split('_')[0]
        patients.add(pat)
print(f'Пациенты из группы {data_path.split("/")[-2]}: {patients}')
emg = 2 # правая рука
# Out:
# Пациенты из группы Margo_DATA_Control_rassl: {'Хвал0207.txt', 'Сидо0205.txt', 'Лега0204.txt', 'Черк0208.txt', 'Аста0201.txt', 'Фрол0206.txt', 'Керш0203.txt', 'Дюки0202.txt'}

# %% [markdown]
# К сожалению, с именами пациентов проблемы, поэтому приходится их кодировать.

# %%
pat2id = {'Черк0208.txt':0, 'Керш0203.txt':1, 'Аста0201.txt':2, 'Лега0204.txt':3, 'Хвал0207.txt':4, 'Дюки0202.txt':5, 'Сидо0205.txt':6, 'Фрол0206.txt':7,
         'Шелу0209.txt':8, 'Сави0208.txt':9, 'Наза0205.txt':10, 'Колг0203.txt':11, 'Савв0207.txt':12, 'Медв0204.txt':13, 'Кова0202.txt':14, 'Ерми0201.txt':15, 'Погр0206.txt':16,
          'Голу0203.txt':17, 'Ротм0208.txt':18, 'Хлюс02011.txt':19, 'Грек0204.txt':20, 'Губа0205.txt':21, 'Серо0209.txt':22, 'Гава0202.txt':23, 'Бело0201.txt':24, 'Пана0207.txt':25, 'Соло02010.txt':26, 'Павл0206.txt':27,
         'Молю02010.txt':28, 'Тихо02013.txt':29, 'Муха02011.txt':30, 'Кудр0203.txt':31, 'Соко02012.txt':32, 'Ершо0202.txt':33, 'Купр0204 .txt':34, 'Куту0205.txt':35, 'Луче0207.txt':36, 'Даке0201.txt':37, 'Лити0206.txt':38, 'Макс0208.txt':39, 'Миро0209.txt':40}

# %%
with open(strFileName, "a",encoding='utf8',newline='') as f:
    writer = csv.writer(f, delimiter=',',  quoting=csv.QUOTE_NONE)
    for patient in patients:
        features = extract_wavetrains([patient], data_path, emg)
        sorted_features = sort_by_time(features)     
        for key in sorted_features:
            writer.writerow(['control']+ [pat2id[patient]] + [key] +  sorted_features[key])
# Out:
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Хвал0207.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Хвал0207.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Хвал0207.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Хвал0207.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Хвал0207.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Хвал0207.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Хвал0207.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Хвал0207.txt_EMG2Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Сидо0205.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Сидо0205.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Сидо0205.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Сидо0205.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Сидо0205.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Сидо0205.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Сидо0205.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Сидо0205.txt_EMG2Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Лега0204.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Лега0204.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Лега0204.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Лега0204.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Лега0204.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Лега0204.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Лега0204.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Лега0204.txt_EMG2Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Черк0208.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Черк0208.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Черк0208.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Черк0208.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Черк0208.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Черк0208.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Черк0208.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Черк0208.txt_EMG2Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Аста0201.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Аста0201.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Аста0201.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Аста0201.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Аста0201.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Аста0201.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Аста0201.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Аста0201.txt_EMG2Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Фрол0206.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Фрол0206.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Фрол0206.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Фрол0206.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Фрол0206.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Фрол0206.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Фрол0206.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Фрол0206.txt_EMG2Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Керш0203.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Керш0203.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Керш0203.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Керш0203.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Керш0203.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Керш0203.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Керш0203.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Керш0203.txt_EMG2Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Дюки0202.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Дюки0202.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Дюки0202.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Дюки0202.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Дюки0202.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Дюки0202.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Дюки0202.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Дюки0202.txt_EMG2Phase.mat

# %% [markdown]
# #### Данные для БП левый

# %%
data_path = 'C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl/'
patients = set()
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]
# filter the files by name
for f in onlyfiles:
    if f[-3:]=='txt':
        pat = f.split('_')[0]
        patients.add(pat)
print(f'Пациенты из группы {data_path.split("/")[-2]}: {patients}')
emg = 1
# Out:
# Пациенты из группы Margo_DATA_Left_rassl: {'Ерми0201.txt', 'Шелу0209.txt', 'Медв0204.txt', 'Колг0203.txt', 'Кова0202.txt', 'Погр0206.txt', 'Сави0208.txt', 'Савв0207.txt', 'Наза0205.txt'}

# %%
with open(strFileName, "a",encoding='utf8',newline='') as f:
    writer = csv.writer(f, delimiter=',',  quoting=csv.QUOTE_NONE)
    for patient in patients:
        features = extract_wavetrains([patient], data_path, emg)
        sorted_features = sort_by_time(features)     
        for key in sorted_features:
            writer.writerow(['PDL']+ [pat2id[patient]] + [key] +  sorted_features[key])
# Out:
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Ерми0201.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Ерми0201.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Ерми0201.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Ерми0201.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Ерми0201.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Ерми0201.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Ерми0201.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Ерми0201.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Шелу0209.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Шелу0209.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Шелу0209.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Шелу0209.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Шелу0209.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Шелу0209.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Шелу0209.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Шелу0209.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Медв0204.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Медв0204.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Медв0204.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Медв0204.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Медв0204.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Медв0204.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Медв0204.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Медв0204.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Колг0203.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Колг0203.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Колг0203.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Колг0203.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Колг0203.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Колг0203.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Колг0203.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Колг0203.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Кова0202.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Кова0202.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Кова0202.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Кова0202.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Кова0202.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Кова0202.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Кова0202.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Кова0202.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Погр0206.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Погр0206.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Погр0206.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Погр0206.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Погр0206.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Погр0206.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Погр0206.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Погр0206.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Сави0208.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Сави0208.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Сави0208.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Сави0208.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Сави0208.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Сави0208.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Сави0208.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Сави0208.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Савв0207.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Савв0207.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Савв0207.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Савв0207.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Савв0207.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Савв0207.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Савв0207.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Савв0207.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Наза0205.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Наза0205.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Наза0205.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Наза0205.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Наза0205.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Наза0205.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Наза0205.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Left_rassl//Наза0205.txt_EMG1Phase.mat

# %% [markdown]
# #### Данные для БП правый

# %%
data_path = 'C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl/'
patients = set()
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]
# filter the files by name
for f in onlyfiles:
    if f[-3:]=='txt':
        pat = f.split('_')[0]
        patients.add(pat)
print(f'Пациенты из группы {data_path.split("/")[-2]}: {patients}')
emg = 2
# Out:
# Пациенты из группы Margo_DATA_Right_rassl: {'Пана0207.txt', 'Грек0204.txt', 'Гава0202.txt', 'Павл0206.txt', 'Соло02010.txt', 'Бело0201.txt', 'Ротм0208.txt', 'Серо0209.txt', 'Губа0205.txt', 'Голу0203.txt', 'Хлюс02011.txt'}

# %%
with open(strFileName, "a",encoding='utf8',newline='') as f:
    writer = csv.writer(f, delimiter=',',  quoting=csv.QUOTE_NONE)
    for patient in patients:
        features = extract_wavetrains([patient], data_path, emg)
        sorted_features = sort_by_time(features)     
        for key in sorted_features:
            writer.writerow(['PDR']+ [pat2id[patient]] + [key] +  sorted_features[key])
# Out:
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Пана0207.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Пана0207.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Пана0207.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Пана0207.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Пана0207.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Пана0207.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Пана0207.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Пана0207.txt_EMG2Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Грек0204.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Грек0204.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Грек0204.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Грек0204.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Грек0204.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Грек0204.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Грек0204.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Грек0204.txt_EMG2Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Гава0202.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Гава0202.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Гава0202.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Гава0202.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Гава0202.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Гава0202.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Гава0202.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Гава0202.txt_EMG2Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Павл0206.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Павл0206.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Павл0206.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Павл0206.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Павл0206.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Павл0206.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Павл0206.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Павл0206.txt_EMG2Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Соло02010.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Соло02010.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Соло02010.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Соло02010.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Соло02010.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Соло02010.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Соло02010.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Соло02010.txt_EMG2Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Бело0201.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Бело0201.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Бело0201.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Бело0201.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Бело0201.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Бело0201.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Бело0201.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Бело0201.txt_EMG2Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Ротм0208.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Ротм0208.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Ротм0208.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Ротм0208.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Ротм0208.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Ротм0208.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Ротм0208.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Ротм0208.txt_EMG2Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Серо0209.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Серо0209.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Серо0209.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Серо0209.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Серо0209.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Серо0209.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Серо0209.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Серо0209.txt_EMG2Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Губа0205.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Губа0205.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Губа0205.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Губа0205.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Губа0205.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Губа0205.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Губа0205.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Губа0205.txt_EMG2Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Голу0203.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Голу0203.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Голу0203.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Голу0203.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Голу0203.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Голу0203.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Голу0203.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Голу0203.txt_EMG2Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Хлюс02011.txt_EMG2Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Хлюс02011.txt_EMG2DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Хлюс02011.txt_EMG2BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Хлюс02011.txt_EMG2Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Хлюс02011.txt_EMG2Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Хлюс02011.txt_EMG2DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Хлюс02011.txt_EMG2Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Right_rassl//Хлюс02011.txt_EMG2Phase.mat

# %% [markdown]
# #### Данные для ЭТ

# %%
data_path = 'C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl/'
patients = set()
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]
# filter the files by name
for f in onlyfiles:
    if f[-3:]=='txt':
        pat = f.split('_')[0]
        patients.add(pat)
print(f'Пациенты из группы {data_path.split("/")[-2]}: {patients}')
emg = 2
# Out:
# Пациенты из группы Margo_DATA_ET_rassl: {'Лити0206.txt', 'Макс0208.txt', 'Молю02010.txt', 'Миро0209.txt', 'Даке0201.txt', 'Луче0207.txt', 'Ершо0202.txt', 'Куту0205.txt', 'Муха02011.txt', 'Купр0204 .txt', 'Кудр0203.txt', 'Соко02012.txt', 'Тихо02013.txt'}

# %%
with open(strFileName, "a",encoding='utf8',newline='') as f:
    writer = csv.writer(f, delimiter=',',  quoting=csv.QUOTE_NONE)
    for patient in patients:
        features = extract_wavetrains([patient], data_path, 1)
        sorted_features = sort_by_time(features)     
        for key in sorted_features:
            writer.writerow(['ET']+ [pat2id[patient]] + [key] +  sorted_features[key])
# Out:
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Лити0206.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Лити0206.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Лити0206.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Лити0206.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Лити0206.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Лити0206.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Лити0206.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Лити0206.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Макс0208.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Макс0208.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Макс0208.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Макс0208.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Макс0208.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Макс0208.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Макс0208.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Макс0208.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Молю02010.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Молю02010.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Молю02010.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Молю02010.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Молю02010.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Молю02010.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Молю02010.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Молю02010.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Миро0209.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Миро0209.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Миро0209.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Миро0209.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Миро0209.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Миро0209.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Миро0209.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Миро0209.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Даке0201.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Даке0201.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Даке0201.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Даке0201.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Даке0201.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Даке0201.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Даке0201.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Даке0201.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Луче0207.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Луче0207.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Луче0207.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Луче0207.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Луче0207.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Луче0207.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Луче0207.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Луче0207.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Ершо0202.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Ершо0202.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Ершо0202.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Ершо0202.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Ершо0202.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Ершо0202.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Ершо0202.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Ершо0202.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Куту0205.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Куту0205.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Куту0205.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Куту0205.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Куту0205.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Куту0205.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Куту0205.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Куту0205.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Муха02011.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Муха02011.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Муха02011.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Муха02011.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Муха02011.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Муха02011.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Муха02011.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Муха02011.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Купр0204 .txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Купр0204 .txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Купр0204 .txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Купр0204 .txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Купр0204 .txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Купр0204 .txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Купр0204 .txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Купр0204 .txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Кудр0203.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Кудр0203.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Кудр0203.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Кудр0203.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Кудр0203.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Кудр0203.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Кудр0203.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Кудр0203.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Соко02012.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Соко02012.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Соко02012.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Соко02012.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Соко02012.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Соко02012.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Соко02012.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Соко02012.txt_EMG1Phase.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Тихо02013.txt_EMG1Freq.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Тихо02013.txt_EMG1DuratPeriods.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Тихо02013.txt_EMG1BandwidthesHz.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Тихо02013.txt_EMG1Time.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Тихо02013.txt_EMG1Ampl.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Тихо02013.txt_EMG1DuratSeconds.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Тихо02013.txt_EMG1Frac_Band.mat
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_ET_rassl//Тихо02013.txt_EMG1Phase.mat

# %%
At this stage we have the data to test our first baseline LSTM model.

# %% [markdown]
# # Часть 2

# %% [markdown]
# # Проверка для Алексея

# %% [markdown]
# Оконное преобразование может понадобиться для того, чтобы визуально разделить наборы данных, а потом придумать предварительное преобразование данных, поступающих в нейросеть. Мы бы воспоспользовались оконным преобразованием, если бы увидели на присланной вами диаграмме неравномерности плотности точек во времени. Но судя по тому, что таких неравномерностей невидно, хвататься надо за другое.
#
# Насколько я помню, у меня закономерности в периодах наблюдались не для всех всплесков, а только для всплесков в ограниченных диапазонах частот, например, от 3 до 21 Гц. Я наблюдал это на правых руках у правотреморных пациентов с БП в расслабленном состоянии. При этом наблюдалась ярко выраженная отрицательная корреляция между длительностью следующих друг за другом всплесков. То есть, после длительного всплеска шел короткий всплеск, а после короткого всплеска шел длинный всплеск. У ЭТ ничего похожего не наблюдалось.
#
# Пожалуйста, попробуйте это как-то визуализировать. Я это визуализировал очень просто. Взял всплески через один, построил 2 вектора: четные всплески, нечетные всплеск. И сунул в скаттер-плот. Получилась ярко выраженная обратная зависимость.По идеи рекурсивная нейросеть тоже должна это отловить. Кстати, можете построить модель сигнала и это проверить, чтобы убедиться, что она это может.

# %%
import pandas as pd

# %%
data_path = 'C:/Users/khokhlovam/Documents/kotelnikov/data/data_lstm_test_complet.csv'
df =pd.read_csv(data_path, header=None, names=range(1564)) #

# %% [markdown]
# Feature order is:  freq, flash_d, bandw, timesing, time_lstm (time since last wavetrain), ampl, duratSec, frac, phase

# %%
df.head(10)
# Out:
#       0     1               2           3           4           5     \
# 0  control     4            freq   17.400000   11.200000   30.500000
# 1  control     4           flash    1.009200    1.523200    0.793000
# 2  control     4       bandwidth    7.700000    3.600000   19.000000
# 3  control     4      timeSignal    0.098000    0.238000    0.256000
# 4  control     4  time_sincelast    0.098000    0.140000    0.018000
# 5  control     4            ampl  115.189682  181.916809  107.035546
# 6  control     4        duratSec    0.058000    0.136000    0.026000
# 7  control     4            frac    0.442529    0.321429    0.622951
# 8  control     4           phase   -0.176576    1.975381   -0.215273
# 9  control     6            freq   36.800000   19.200000   26.400000
#
#          6           7           8           9     ...  1554  1555  1556  \
# 0   19.200000    8.800000   22.900000    6.900000  ...   NaN   NaN   NaN
# 1    1.152000    1.337600    1.007600    1.007400  ...   NaN   NaN   NaN
# 2    7.000000    2.600000   10.700000    3.900000  ...   NaN   NaN   NaN
# 3    0.528000    0.536000    0.802000    0.850000  ...   NaN   NaN   NaN
# 4    0.272000    0.008000    0.266000    0.048000  ...   NaN   NaN   NaN
# 5  113.025248  204.781645  459.905485  206.880764  ...   NaN   NaN   NaN
# 6    0.060000    0.152000    0.044000    0.146000  ...   NaN   NaN   NaN
# 7    0.364583    0.295455    0.467249    0.565217  ...   NaN   NaN   NaN
# 8    0.658635    0.088833   -0.061623   -2.434454  ...   NaN   NaN   NaN
# 9   15.800000   22.000000   21.100000   10.600000  ...   NaN   NaN   NaN
#
#    1557  1558  1559  1560  1561  1562  1563
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 7   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 8   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [10 rows x 1564 columns]

# %% [markdown]
# ## Flash duration experiments

# %%
freq_valid = [3,6.5] # 0 
PD = []
C = []
ET = []
fig, axs = plt.subplots(1,3, figsize=(15,5), sharey=True)
for i in range(0,len(df),9): # take only flash_fr
    label = df.iloc[[i]][0].values[0]
    flash_d = df.iloc[[i+1]].values.tolist()[0]
    freq_range = df.iloc[[i]].values.tolist()[0]
    time_v = df.iloc[[i+3]].values.tolist()[0]
    valid_indexes = [i for i in range(3,len(freq_range)) if str(freq_range[i]) !='nan' and  freq_range[i]>=freq_valid[0] and freq_range[i]<=freq_valid[1]]
    flash_d = [flash_d[x] for x in valid_indexes]
    time_v = [time_v[x] for x in valid_indexes]
    mean_flash = np.mean(flash_d)
    if label == 'control':
        C.append(mean_flash)
    elif label == 'ET':
        ET.append(mean_flash)
    elif label == 'PDR':
        PD.append(mean_flash)
col = ['r','g','b']

flash_d = {"PD":PD, "Control":C, "ET":ET}
for j, key in enumerate(flash_d):
    axs[j].hist(flash_d[key], color=col[j])
    axs[j].set_xlabel('Flash_duration histograms')
    axs[j].set_ylabel('Quantity of patients')
    axs[j].set_title(key)
fig.suptitle('Mean Flash Duration Histogram')
# Out:
# Text(0.5, 0.98, 'Mean Flash Duration Histogram')

# %% [markdown]
# ## Вывод по гистограммам Flash duration
# ЭТ и Контроль не разделяются при любых диапазонах частот.
# БП правые разделяются с контролем, правда, не очень удачно, в диапазонаx [3;6.5].

# %% [markdown]
# ## Mean Bandwidth  experiments

# %%
freq_valid = [5,8] # 0 
PD = []
C = []
ET = []
fig, axs = plt.subplots(1,3, figsize=(15,5), sharey=True)
for i in range(0,len(df),9): # take only flash_fr
    label = df.iloc[[i]][0].values[0]
    bandw_d = df.iloc[[i+2]].values.tolist()[0]
    freq_range = df.iloc[[i]].values.tolist()[0]
    time_v = df.iloc[[i+3]].values.tolist()[0]
    valid_indexes = [i for i in range(3,len(freq_range)) if str(freq_range[i]) !='nan' and  freq_range[i]>=freq_valid[0] and freq_range[i]<=freq_valid[1]]
    bandw_d = [bandw_d[x] for x in valid_indexes]
    time_v = [time_v[x] for x in valid_indexes]
    mean_bandw_d = np.mean(bandw_d)
    if label == 'control':
        C.append(mean_bandw_d)
    elif label == 'ET':
        ET.append(mean_bandw_d)
    elif label == 'PDR':
        PD.append(mean_bandw_d)
col = ['r','g','b']

flash_d = {"PD":PD, "Control":C, "ET":ET}
for j, key in enumerate(flash_d):
    axs[j].hist(flash_d[key], color=col[j])
    axs[j].set_xlabel('Bandwidth histograms')
    axs[j].set_ylabel('Quantity of patients')
    axs[j].set_title(key)
fig.suptitle('Mean Bandwidth Histogram')
# Out:
# Text(0.5, 0.98, 'Mean Bandwidth Histogram')

# %% [markdown]
# ## Вывод по гистограммам Mean Bandwidth
# ЭТ и Контроль не разделяются при любых диапазонах частот.
# БП правые разделяются с контролем, правда, не очень удачно, в диапазонаx [3;6.5].

# %% [markdown]
# ## Amplitude experiments

# %%
freq_valid = [0,2] # 0 
PD = []
C = []
ET = []
fig, axs = plt.subplots(1,3, figsize=(15,5), sharey=True)
for i in range(0,len(df),9): # take only flash_fr
    label = df.iloc[[i]][0].values[0]
    ampl_d = df.iloc[[i+5]].values.tolist()[0]
    freq_range = df.iloc[[i]].values.tolist()[0]
    time_v = df.iloc[[i+3]].values.tolist()[0]
    valid_indexes = [i for i in range(3,len(freq_range)) if str(freq_range[i]) !='nan' and  freq_range[i]>=freq_valid[0] and freq_range[i]<=freq_valid[1]]
    ampl_d = [ampl_d[x] for x in valid_indexes]
    time_v = [time_v[x] for x in valid_indexes]
    mean_ampl_d = np.mean(ampl_d)
    if label == 'control':
        C.append(mean_ampl_d )
    elif label == 'ET':
        ET.append(mean_ampl_d )
    elif label == 'PDR':
        PD.append(mean_ampl_d )
col = ['r','g','b']

flash_d = {"PD":PD, "Control":C, "ET":ET}
for j, key in enumerate(flash_d):
    axs[j].hist(flash_d[key], color=col[j])
    axs[j].set_xlabel('Amplitude histograms')
    axs[j].set_ylabel('Quantity of patients')
    axs[j].set_title(key)
    # axs[j].set_xlim(xmax=1000)

fig.suptitle('Mean Amplitute Histogram')
# Out:
# Text(0.5, 0.98, 'Mean Amplitute Histogram')

# %% [markdown]
# ## Вывод по гистограммам amplitude
# ЭТ и Контроль не разделяются при любых диапазонах частот.
# БП правые и контроль показывают интересные результаты, но это в основном отдельные пациенты, поэтому странно...

# %% [raw]
# ## Frac experiments

# %%
freq_valid = [0,2] # 0 
PD = []
C = []
ET = []
fig, axs = plt.subplots(1,3, figsize=(15,5), sharey=True)
for i in range(0,len(df),9): # take only flash_fr
    label = df.iloc[[i]][0].values[0]
    ampl_d = df.iloc[[i+5]].values.tolist()[0]
    freq_range = df.iloc[[i]].values.tolist()[0]
    time_v = df.iloc[[i+3]].values.tolist()[0]
    valid_indexes = [i for i in range(3,len(freq_range)) if str(freq_range[i]) !='nan' and  freq_range[i]>=freq_valid[0] and freq_range[i]<=freq_valid[1]]
    ampl_d = [ampl_d[x] for x in valid_indexes]
    time_v = [time_v[x] for x in valid_indexes]
    mean_ampl_d = np.mean(ampl_d)
    if label == 'control':
        C.append(mean_ampl_d )
    elif label == 'ET':
        ET.append(mean_ampl_d )
    elif label == 'PDR':
        PD.append(mean_ampl_d )
col = ['r','g','b']

flash_d = {"PD":PD, "Control":C, "ET":ET}
for j, key in enumerate(flash_d):
    axs[j].hist(flash_d[key], color=col[j])
    axs[j].set_xlabel('Amplitude histograms')
    axs[j].set_ylabel('Quantity of patients')
    axs[j].set_title(key)
    # axs[j].set_xlim(xmax=1000)

fig.suptitle('Mean Amplitute Histogram')

# %% [markdown]
# Let's try to plot the wavetrains odd and even for each class of patients :

# %%
fig, axs = plt.subplots(3,2, figsize=(16,10), sharey=True)
for i in range(1,len(df),4): # take only flash_fr
    # print(i, i+2, df.iloc[[i]][0].values[0])
    if df.iloc[[i]][0].values[0] == 'control':
        flash_d = df.iloc[[i]].values.tolist()[0]
        flash_d = [x for x in  flash_d if str(x) != 'nan']
        time_v = df.iloc[[i+2]].values.tolist()[0]
        time_v = [x for x in  time_v if str(x) != 'nan']
        axs[0,0].scatter(flash_d[2::2],time_v[2::2], color='g')
        axs[0,1].scatter(flash_d[3::2],time_v[3::2], color='g')
        axs[0,0].set_title('control')
    elif df.iloc[[i]][0].values[0] == 'ET':
        flash_d = df.iloc[[i]].values.tolist()[0]
        flash_d = [x for x in  flash_d if str(x) != 'nan']
        time_v = df.iloc[[i+2]].values.tolist()[0]
        time_v = [x for x in  time_v if str(x) != 'nan']
        if len(flash_d)<len(time_v):
            time_v = time_v[:(len(flash_d))]
#             print(len(flash_d), len(time_v))
        axs[1,0].scatter(flash_d[2::2],time_v[2::2],color='b')
        axs[1,1].scatter(flash_d[3::2],time_v[3::2],color='b')
        axs[1,0].set_title('ET')
    else:
        flash_d = df.iloc[[i]].values.tolist()[0]
        flash_d = [x for x in  flash_d if str(x) != 'nan']
        time_v = df.iloc[[i+2]].values.tolist()[0]
        time_v = [x for x in  time_v if str(x) != 'nan']
        if len(flash_d)<len(time_v):
            time_v = time_v[:(len(flash_d))]
#             print(len(flash_d), len(time_v))
        axs[2,0].scatter(flash_d[2::2],time_v[2::2], color='r')
        axs[2,1].scatter(flash_d[3::2],time_v[3::2], color='r')
        axs[2,0].set_title('PD')
    fig.suptitle('Even and odd scatter plots')

# %%
freq_range = [3,21]
fig, axs = plt.subplots(3,2, figsize=(16,10), sharey=True)
for i in range(1,len(df),4): # take only flash_fr
#     print(i, i+2, df.iloc[[i]][0].values[0])
    if df.iloc[[i]][0].values[0] == 'control':
        flash_d = df.iloc[[i]].values.tolist()[0]
        valid_indexes = [i for i in range(2,len(flash_d)) if str(flash_d[i]) !='nan' and  flash_d[i]>freq_range[0] and flash_d[i]<freq_range[1]]
        flash_d = [flash_d[x] for x in valid_indexes]
        time_v = df.iloc[[i+2]].values.tolist()[0]
        time_v = [time_v[x] for x in valid_indexes]
        axs[0,0].scatter(flash_d[0::2],time_v[0::2], color='g')
        axs[0,1].scatter(flash_d[1::2],time_v[1::2], color='g')
        axs[0,0].set_title('control')
    elif df.iloc[[i]][0].values[0] == 'ET':
        flash_d = df.iloc[[i]].values.tolist()[0]
        flash_d = [flash_d[x] for x in valid_indexes]
        time_v = df.iloc[[i+2]].values.tolist()[0]
        time_v = [time_v[x] for x in valid_indexes]
        axs[1,0].scatter(flash_d[0::2],time_v[0::2], color='b')
        axs[1,1].scatter(flash_d[1::2],time_v[1::2], color='b')
        axs[1,0].set_title('ET')
    else:
        flash_d = df.iloc[[i]].values.tolist()[0]
        flash_d = [flash_d[x] for x in valid_indexes]
        time_v = df.iloc[[i+2]].values.tolist()[0]
        time_v = [time_v[x] for x in valid_indexes]
        axs[2,0].scatter(flash_d[0::2],time_v[0::2], color='r')
        axs[2,1].scatter(flash_d[1::2],time_v[1::2], color='r')
        axs[2,0].set_title('PD')
    fig.suptitle('Even and odd scatter plots')

# %% [markdown]
# Насколько я помню, у меня закономерности в периодах наблюдались не для всех всплесков, а только для всплесков в ограниченных диапазонах частот, например, от 3 до 21 Гц. Я наблюдал это на правых руках у правотреморных пациентов с БП в расслабленном состоянии. При этом наблюдалась ярко выраженная отрицательная корреляция между длительностью следующих друг за другом всплесков. То есть, после длительного всплеска шел короткий всплеск, а после короткого всплеска шел длинный всплеск. У ЭТ ничего похожего не наблюдалось.

# %%
freq_valid = [3,21] # 0 
fig, axs = plt.subplots(3,2, figsize=(16,10), sharey=True)
for i in range(0,len(df),4): # take only flash_fr
    label = df.iloc[[i]][0].values[0]
    flash_d = df.iloc[[i]].values.tolist()[0]
    freq_range = df.iloc[[i+1]].values.tolist()[0]
    time_v = df.iloc[[i+3]].values.tolist()[0]
    valid_indexes = [i for i in range(2,len(freq_range)) if str(freq_range[i]) !='nan' and  freq_range[i]>freq_valid[0] and freq_range[i]<freq_valid[1]]
    flash_d = [flash_d[x] for x in valid_indexes]
    time_v = [time_v[x] for x in valid_indexes]
    if label == 'control':
        c = 'g'
        j = 0
        text = 'control'        
    elif label == 'ET':
        c = 'b'
        j = 1
        text = 'ET' 
    else:
        c = 'r'
        j = 2
        text = 'PD' 
    axs[j,0].scatter(time_v[0::2], flash_d[0::2], color=c)
    axs[j,1].scatter(time_v[1::2],flash_d[1::2], color=c)
    axs[j,0].set_xlabel('Time between the  consecutive wavetrains')
    axs[j,0].set_ylabel('Flash_duration')
    axs[j,0].set_title(text)
    fig.suptitle('Even and odd scatter plots')

# %% [markdown]
# Маргарита, подождите фильтровать частоты. Давайте сначала убедимся, что мы строим одни и те же картинки. На моих картинках на оси х отложено duration всплеска, а у - duration  следующего всплеска.
#  То есть я разделил все всплески на чётные и  нечетные и тупо использовал нечетные в качестве х, а чётные в качестве у или наоборот. Поэтому диапазон значений по осям х и у примерно одинаковый. А у вас он разный. Чего быть никак не может :-)
# Вот у меня на картинке слева БП, а справа ЭТ.

# %%
freq_valid = [3,21] # 0 
fig, axs = plt.subplots(3,1, figsize=(5,15), sharey=True)
for i in range(0,len(df),4): # take only flash_fr
    label = df.iloc[[i]][0].values[0]
    flash_d = df.iloc[[i+1]].values.tolist()[0]
    freq_range = df.iloc[[i]].values.tolist()[0]
    time_v = df.iloc[[i+3]].values.tolist()[0]
    valid_indexes = [i for i in range(2,len(freq_range)) if str(freq_range[i]) !='nan' and  freq_range[i]>freq_valid[0] and freq_range[i]<freq_valid[1]]
    flash_d = [flash_d[x] for x in valid_indexes]
    time_v = [time_v[x] for x in valid_indexes]
    if label == 'control':
        c = 'g'
        j = 0
        text = 'control'        
    elif label == 'ET':
        c = 'b'
        j = 1
        text = 'ET' 
    else:
        c = 'r'
        j = 2
        text = 'PD' 
    even=flash_d[0::2]
    odd =flash_d[1::2]
    # only if the number of wavetrains is odd
    min_len = min(len(even),len(odd))
    even=even[:min_len]
    odd=odd[:min_len]
    axs[j].scatter(even, odd, color=c)
    axs[j].set_xlabel('Flash_duration even wavetrains')
    axs[j].set_ylabel('Flash_duration odd wavetrains')
    axs[j].set_title(text)
    fig.suptitle('Even and odd  plots')

# %% [markdown]
# здесь следует оменить, что я не разделяю БП левых и правых, они все тут.
#
#
# Словами скажу только, что при сравнении правой треморной руки у БП и правой руки у контроля на частотной диаграмме примерно на частоте 6 Гц наступает коренной перелом, и большое синее облако превращается в большое красное облако. Похоже, что эффект ещё более сильный, чем те, что мы описали в статье в Sensors. Из этого можно сделать следующий вывод. Зная центральную частоту и длительность всплесков,  по этим двум параметрам можно сконструировать простейшие правило, которое будет отличать бп от контроля. Очень странно, что нейросети с этим не справляются. Вся надежда на вас. Только вы можете догадаться, что мы не так суем в нейросети, что они не способны найти решения, лежащие на поверхности :-)
#
# Построю теперь только БП правый и контроль, возьмем частоты от 1 до 20 Гц, построим как и выше  flash_duration.

# %%
freq_valid = [0,6] # 0 
fig, axs = plt.subplots(figsize=(18,9))
for i in range(0,len(df),4): # take only flash_fr
    label = df.iloc[[i]][0].values[0]
    flash_d = df.iloc[[i+1]].values.tolist()[0]
    freq_range = df.iloc[[i]].values.tolist()[0]
    time_v = df.iloc[[i+3]].values.tolist()[0]
    valid_indexes = [i for i in range(2,len(freq_range)) if str(freq_range[i]) !='nan' and  freq_range[i]>freq_valid[0] and freq_range[i]<freq_valid[1]]
    flash_d = [flash_d[x] for x in valid_indexes]
    time_v = [time_v[x] for x in valid_indexes]
    if label == 'control':
        c = 'g' 
    elif label == 'PDR':
        c = 'r'
    else:
        continue
    even=flash_d[0::2]
    odd =flash_d[1::2]
    # only if the number of wavetrains is odd
    min_len = min(len(even),len(odd))
    even=even[:min_len]
    odd=odd[:min_len]
    axs.scatter(even, odd, color=c)
axs.set_xlabel('Flash_duration even wavetrains')
axs.set_ylabel('Flash_duration odd wavetrains')
axs.set_title(text)
fig.suptitle('Even and odd  plots')
# Out:
# Text(0.5, 0.98, 'Even and odd  plots')

# %%
Построю теперь только БП правый и контроль, возьмем частоты от 30 до 40 Гц (почти все), построим frequency, получим красоту...

# %%
freq_valid = [0,20] # 0 
fig, axs = plt.subplots(figsize=(18,9))
for i in range(0,len(df),4): # take only flash_fr
    label = df.iloc[[i]][0].values[0]
    flash_d = df.iloc[[i+1]].values.tolist()[0]
    freq_range = df.iloc[[i]].values.tolist()[0]
    time_v = df.iloc[[i+3]].values.tolist()[0]
    valid_indexes = [i for i in range(2,len(freq_range)) if str(freq_range[i]) !='nan' and  freq_range[i]>freq_valid[0] and freq_range[i]<freq_valid[1]]
    flash_d = [flash_d[x] for x in valid_indexes]
    freq_range_d = [freq_range[x] for x in valid_indexes]
    time_v = [time_v[x] for x in valid_indexes]
    if label == 'control':
        c = 'g' 
    elif label == 'PDL' :#or label == 'PDR'
        c = 'r'
    else:
        continue
    even=freq_range_d[0::2]
    odd =freq_range_d[1::2]
    # only if the number of wavetrains is odd
    min_len = min(len(even),len(odd))
    even=even[:min_len]
    odd=odd[:min_len]
    axs.scatter(even, odd, color=c)
axs.set_xlabel('Freq even wavetrains')
axs.set_ylabel('Freq odd wavetrains')
axs.set_title(text)
fig.suptitle('Even and odd  plots')
# Out:
# Text(0.5, 0.98, 'Even and odd  plots')

# %% [markdown]
# Сейчас я обнаружил, что закономерности с duration in periods and in seconds есть не только у правотреморнвх, но и у левотреморных БП. Причем у левотреморных эффект даже сильнее. Из этого следует, что, если вручную отфильтровать всплески с центральной частотой меньше 6 Гц и сравнить длительность в периодах всплесков БП и контроля, отличия должны быть увидены. Во первых, на гистограммах, а во вторых, методами машинного обучения, включая нейросети. Эффекты очень сильные.
# Если ничего не получится, то когда я приеду в Москву, сядем за компьютер и будем по шагами сравнивать все наши файлы, чтобы понять, откуда такой полтергейс

# %%
freq_valid = [0,6.1] # 0 
fig, axs = plt.subplots(figsize=(18,9))
for i in range(0,len(df),4): # take only flash_fr
    label = df.iloc[[i]][0].values[0]
    flash_d = df.iloc[[i+1]].values.tolist()[0]
    freq_range = df.iloc[[i]].values.tolist()[0]
    time_v = df.iloc[[i+3]].values.tolist()[0]
    valid_indexes = [i for i in range(2,len(freq_range)) if str(freq_range[i]) !='nan' and  freq_range[i]>freq_valid[0] and freq_range[i]<freq_valid[1]]
    flash_d = [flash_d[x] for x in valid_indexes]
    freq_range_d = [freq_range[x] for x in valid_indexes]
    time_v = [time_v[x] for x in valid_indexes]
    if label == 'control':
        c = 'g' 
    elif label == 'PDL' :#or label == 'PDR'
        c = 'r'
    else:
        continue
    even=flash_d[0::2]
    odd =flash_d[1::2]
    # only if the number of wavetrains is odd
    min_len = min(len(even),len(odd))
    even=even[:min_len]
    odd=odd[:min_len]
    axs.scatter(even, odd, color=c)
axs.set_xlabel('Flash duration periods even wavetrains')
axs.set_ylabel('Flash duration periods odd wavetrains')
axs.set_title(text)
fig.suptitle('Even and odd  plots for PD Left and Control')
# Out:
# Text(0.5, 0.98, 'Even and odd  plots for PD Left and Control')

# %%
data_path = 'C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl/'
patients = set()
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]
# filter the files by name
for f in onlyfiles:
    if f[-3:]=='txt':
        pat = f.split('_')[0]
        patients.add(pat)
print(f'Пациенты из группы {data_path.split("/")[-2]}: {patients}')
# Out:
# Пациенты из группы Margo_DATA_Control_rassl: {'Аста0201.txt', 'Фрол0206.txt', 'Хвал0207.txt', 'Керш0203.txt', 'Дюки0202.txt', 'Черк0208.txt', 'Лега0204.txt', 'Сидо0205.txt'}

# %%
mean_flash_list = []
emg = 2
for patient in patients:
    Flash_Durat_signal = load_parameter(patient,emg,'DuratPeriods',data_path)
    mean_flash_list.append(np.mean(Flash_Durat_signal))
    print(np.mean(Flash_Durat_signal))
    
plt.hist(mean_flash_list, color='b')
plt.xlabel('Flash_duration histograms')
plt.ylabel('Quantity of patients')
plt.title("COntrol Right mean Duration Periods")
# Out:
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Аста0201.txt_EMG2DuratPeriods.mat
# 1.2997370139968893
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Фрол0206.txt_EMG2DuratPeriods.mat
# 1.2619415050426577
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Хвал0207.txt_EMG2DuratPeriods.mat
# 1.3097023325808854
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Керш0203.txt_EMG2DuratPeriods.mat
# 1.3125957325746793
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Дюки0202.txt_EMG2DuratPeriods.mat
# 1.3095372641509437
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Черк0208.txt_EMG2DuratPeriods.mat
# 1.2963176186645313
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Лега0204.txt_EMG2DuratPeriods.mat
# 1.2953241210139006
# C:/Users/khokhlovam/Documents/kotelnikov/data/Параметры всплесков - рассл/Margo_DATA_Control_rassl//Сидо0205.txt_EMG2DuratPeriods.mat
# 1.278307305577375
# Text(0.5, 1.0, 'COntrol Right mean Duration Periods')
