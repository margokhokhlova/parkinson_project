# %% [markdown]
# # RNN model check

# %%
import sys
import numpy as np
import torch
sys.path.append('/home/mkhokhlo/projects/kotelnikov/scripts/scripts/vanilla')
sys.path.append('/home/mkhokhlo/projects/kotelnikov/scripts/scripts/')
from torch.utils.data import  Dataset, DataLoader
import torch.nn as nn

# %%
data_path = '/home/mkhokhlo/projects/kotelnikov/scripts/scripts/data/data_lstm_august24_PDET_left_right.csv'
int2feat ={0: 'ampl', 1: 'BandwidthesHz', 2: 'Bottom', 3: 'flash_periods', 4: 'flash_seconds', 5: 'frac_band', 6: 'freq', 7: 'phase', 8: 'Psi0',
           9: 'top', 10: 'time_sincelast'}

# %%
int2feat_all ={0: 'ampl', 1: 'BandwidthesHz', 2: 'Bottom', 3: 'flash_periods', 4: 'flash_seconds', 5: 'frac_band', 6: 'freq', 7:'left', 
                8: 'phase', 9: 'Psi0', 10: 'right',11: 'timeSigal', 12 :'top', 13: 'time_sincelast'}
# ampl
# BandwidthesHz
# Bottom
# flash_periods
# flash_seconds
# frac_band
# freq
# left
# phase
# Psi0
# right
# timeSignal
# top
# time_sincelast

# %%
from rnn import SimpleRNN, GaitDataset
from feature_selection import get_feature

# %%
current_feat = range(14)#[0,1,2,3,4,5,6,8,9,12,13]
num_feat = len(current_feat)
# Initialize lists to store the features and labels
PDL_features = [0]*num_feat
ETL_features = [0]*num_feat    

#     All but left, right, timeSignal.    
for i, j in enumerate(current_feat):
    Xf1_PDL, Xf1_ETL = get_feature(j,data_path= data_path,  min_len_established = 600, skip_patients = [55, 70,71,72,73,74,75,76])
    Xf1_PDL = np.array(Xf1_PDL)  # Shape: (14, 600)
    Xf1_ETL = np.array(Xf1_ETL)  # Shape: (14, 600)
    #print(Xf1_ETL.shape)
    PDL_features[i]= Xf1_PDL
    ETL_features[i]= Xf1_ETL         

PDL_features = np.array(PDL_features)  # Shape (14, 14, 600)
PDL_features = np.transpose(PDL_features, (1, 0, 2))  # Shape (14, 14, 600)


# Reshape ETL_features to (21, 14, 600)
ETL_features = np.array(ETL_features)  # Shape (14, 21, 600)
ETL_features = np.transpose(ETL_features, (1, 0, 2))  # Shape (21, 14, 600)

assert(PDL_features.shape == ETL_features.shape)

# %%
#min max normalization for the features for TRAIN
train_indices = range(14)
all_train = np.concatenate((PDL_features, ETL_features), axis=0) 

all_train =torch.tensor(all_train) #N train, 14,600
# Step 1: Reshape to combine patients and time dimensions for feature normalization
reshaped_features = all_train.permute(1, 0, 2).reshape(num_feat, -1)  # Shape: (14, N train *600)

# Step 2: Compute min and max values for each feature
min_values = reshaped_features.min(dim=1, keepdim=True).values  # Shape: (14, 1)
max_values = reshaped_features.max(dim=1, keepdim=True).values  # Shape: (14, 1)

normalized_features_train  = (reshaped_features - min_values) / (max_values - min_values + 1e-8)  # Avoid division by zero
normalized_features_train = normalized_features_train.reshape(num_feat, len(train_indices)*2, 600) 
normalized_features_train  = normalized_features_train.permute(1, 0, 2) # reshape back



PDL_train = normalized_features_train[:len(train_indices),:,:]
ETL_train =  normalized_features_train[len(train_indices):,:,:]

# Create dataset and dataloader
gait_dataset_train = GaitDataset(PDL_train, ETL_train)
dataloader = DataLoader(gait_dataset_train, batch_size=4, shuffle=True)

# %%
# Model parameters
input_size = num_feat  # Number of features
hidden_size = 8  # Hidden size for RNN
output_size = 1   # Binary classification (PDL or ETL)
num_epochs = 500

model = SimpleRNN(input_size, hidden_size, output_size)


    # Training setup
criterion = nn.BCELoss()  # Binary Cross Entropy Loss for binary classification
optimizer = torch.optim.Adam(model.parameters(), lr=0.0005)

# Training loop

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device = torch.device('cpu')
model.to(device)
model.train()
for epoch in range(num_epochs):
            total_loss = 0.0
            correct_predictions = 0
            total_samples = 0
            
            for inputs, labels in dataloader:
                inputs, labels = inputs.to(device), labels.to(device)
                
                optimizer.zero_grad()
                
                # Forward pass
                outputs = model(inputs)
                loss = criterion(outputs.squeeze(), labels.float())
                
                # Backward and optimize
                loss.backward()
                optimizer.step()
                
                # Track the total loss
                total_loss += loss.item() * inputs.size(0)
                
                # Convert probabilities to binary predictions (0 or 1)
                predicted = (outputs.squeeze() >= 0.5).long()
                
                # Track the number of correct predictions
                correct_predictions += (predicted == labels).sum().item()
                total_samples += labels.size(0)
            
            # Calculate average loss and accuracy
            avg_loss = total_loss / total_samples
            accuracy = correct_predictions / total_samples * 100
            
            print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, Accuracy: {accuracy:.2f}%")
# Out:
# Epoch [1/500], Loss: 0.6771, Accuracy: 50.00%
# Epoch [2/500], Loss: 0.6718, Accuracy: 60.71%
# Epoch [3/500], Loss: 0.6664, Accuracy: 67.86%
# Epoch [4/500], Loss: 0.6610, Accuracy: 71.43%
# Epoch [5/500], Loss: 0.6556, Accuracy: 71.43%
# Epoch [6/500], Loss: 0.6502, Accuracy: 71.43%
# Epoch [7/500], Loss: 0.6446, Accuracy: 78.57%
# Epoch [8/500], Loss: 0.6390, Accuracy: 82.14%
# Epoch [9/500], Loss: 0.6333, Accuracy: 82.14%
# Epoch [10/500], Loss: 0.6274, Accuracy: 82.14%
# Epoch [11/500], Loss: 0.6212, Accuracy: 85.71%
# Epoch [12/500], Loss: 0.6148, Accuracy: 85.71%
# Epoch [13/500], Loss: 0.6081, Accuracy: 85.71%
# Epoch [14/500], Loss: 0.6010, Accuracy: 85.71%
# Epoch [15/500], Loss: 0.5934, Accuracy: 85.71%
# Epoch [16/500], Loss: 0.5854, Accuracy: 85.71%
# Epoch [17/500], Loss: 0.5769, Accuracy: 89.29%
# Epoch [18/500], Loss: 0.5679, Accuracy: 89.29%
# Epoch [19/500], Loss: 0.5585, Accuracy: 89.29%
# Epoch [20/500], Loss: 0.5486, Accuracy: 89.29%
# Epoch [21/500], Loss: 0.5382, Accuracy: 89.29%
# Epoch [22/500], Loss: 0.5272, Accuracy: 85.71%
# Epoch [23/500], Loss: 0.5155, Accuracy: 85.71%
# Epoch [24/500], Loss: 0.5031, Accuracy: 85.71%
# Epoch [25/500], Loss: 0.4900, Accuracy: 85.71%
# Epoch [26/500], Loss: 0.4778, Accuracy: 85.71%
# Epoch [27/500], Loss: 0.4767, Accuracy: 85.71%
# Epoch [28/500], Loss: 0.4570, Accuracy: 85.71%
# Epoch [29/500], Loss: 0.4548, Accuracy: 85.71%
# Epoch [30/500], Loss: 0.4457, Accuracy: 85.71%
# Epoch [31/500], Loss: 0.4368, Accuracy: 85.71%
# Epoch [32/500], Loss: 0.4292, Accuracy: 85.71%
# Epoch [33/500], Loss: 0.4376, Accuracy: 82.14%
# Epoch [34/500], Loss: 0.4281, Accuracy: 85.71%
# Epoch [35/500], Loss: 0.4526, Accuracy: 78.57%
# Epoch [36/500], Loss: 0.4466, Accuracy: 78.57%
# Epoch [37/500], Loss: 0.4071, Accuracy: 85.71%
# Epoch [38/500], Loss: 0.4027, Accuracy: 85.71%
# Epoch [39/500], Loss: 0.4342, Accuracy: 82.14%
# Epoch [40/500], Loss: 0.3965, Accuracy: 85.71%
# Epoch [41/500], Loss: 0.4350, Accuracy: 78.57%
# Epoch [42/500], Loss: 0.4474, Accuracy: 78.57%
# Epoch [43/500], Loss: 0.4483, Accuracy: 78.57%
# Epoch [44/500], Loss: 0.4435, Accuracy: 78.57%
# Epoch [45/500], Loss: 0.4276, Accuracy: 78.57%
# Epoch [46/500], Loss: 0.3821, Accuracy: 85.71%
# Epoch [47/500], Loss: 0.3782, Accuracy: 85.71%
# Epoch [48/500], Loss: 0.4410, Accuracy: 82.14%
# Epoch [49/500], Loss: 0.4183, Accuracy: 82.14%
# Epoch [50/500], Loss: 0.3771, Accuracy: 85.71%
# Epoch [51/500], Loss: 0.4418, Accuracy: 78.57%
# Epoch [52/500], Loss: 0.4571, Accuracy: 78.57%
# Epoch [53/500], Loss: 0.4714, Accuracy: 78.57%
# Epoch [54/500], Loss: 0.4898, Accuracy: 75.00%
# Epoch [55/500], Loss: 0.4921, Accuracy: 75.00%
# Epoch [56/500], Loss: 0.4859, Accuracy: 75.00%
# Epoch [57/500], Loss: 0.4660, Accuracy: 78.57%
# Epoch [58/500], Loss: 0.4516, Accuracy: 78.57%
# Epoch [59/500], Loss: 0.4409, Accuracy: 78.57%
# Epoch [60/500], Loss: 0.4255, Accuracy: 78.57%
# Epoch [61/500], Loss: 0.3851, Accuracy: 85.71%
# Epoch [62/500], Loss: 0.3614, Accuracy: 85.71%
# Epoch [63/500], Loss: 0.4566, Accuracy: 82.14%
# Epoch [64/500], Loss: 0.6637, Accuracy: 71.43%
# Epoch [65/500], Loss: 0.6693, Accuracy: 67.86%
# Epoch [66/500], Loss: 0.5044, Accuracy: 85.71%
# Epoch [67/500], Loss: 0.4542, Accuracy: 82.14%
# Epoch [68/500], Loss: 0.4105, Accuracy: 82.14%
# Epoch [69/500], Loss: 0.3612, Accuracy: 85.71%
# Epoch [70/500], Loss: 0.4176, Accuracy: 78.57%
# Epoch [71/500], Loss: 0.4370, Accuracy: 78.57%
# Epoch [72/500], Loss: 0.4475, Accuracy: 78.57%
# Epoch [73/500], Loss: 0.4663, Accuracy: 78.57%
# Epoch [74/500], Loss: 0.4786, Accuracy: 75.00%
# Epoch [75/500], Loss: 0.4815, Accuracy: 75.00%
# Epoch [76/500], Loss: 0.4793, Accuracy: 75.00%
# Epoch [77/500], Loss: 0.4715, Accuracy: 78.57%
# Epoch [78/500], Loss: 0.4544, Accuracy: 78.57%
# Epoch [79/500], Loss: 0.4427, Accuracy: 78.57%
# Epoch [80/500], Loss: 0.4346, Accuracy: 78.57%
# Epoch [81/500], Loss: 0.4247, Accuracy: 78.57%
# Epoch [82/500], Loss: 0.4100, Accuracy: 78.57%
# Epoch [83/500], Loss: 0.3750, Accuracy: 85.71%
# Epoch [84/500], Loss: 0.3581, Accuracy: 85.71%
# Epoch [85/500], Loss: 0.4129, Accuracy: 82.14%
# Epoch [86/500], Loss: 0.4219, Accuracy: 82.14%
# Epoch [87/500], Loss: 0.3568, Accuracy: 89.29%
# Epoch [88/500], Loss: 0.3570, Accuracy: 85.71%
# Epoch [89/500], Loss: 0.3637, Accuracy: 85.71%
# Epoch [90/500], Loss: 0.3782, Accuracy: 85.71%
# Epoch [91/500], Loss: 0.3727, Accuracy: 85.71%
# Epoch [92/500], Loss: 0.3552, Accuracy: 85.71%
# Epoch [93/500], Loss: 0.3515, Accuracy: 85.71%
# Epoch [94/500], Loss: 0.3488, Accuracy: 85.71%
# Epoch [95/500], Loss: 0.3500, Accuracy: 89.29%
# Epoch [96/500], Loss: 0.3582, Accuracy: 85.71%
# Epoch [97/500], Loss: 0.3440, Accuracy: 85.71%
# Epoch [98/500], Loss: 0.3447, Accuracy: 85.71%
# Epoch [99/500], Loss: 0.3467, Accuracy: 85.71%
# Epoch [100/500], Loss: 0.3545, Accuracy: 85.71%
# Epoch [101/500], Loss: 0.3501, Accuracy: 85.71%
# Epoch [102/500], Loss: 0.3417, Accuracy: 85.71%
# Epoch [103/500], Loss: 0.3379, Accuracy: 85.71%
# Epoch [104/500], Loss: 0.3339, Accuracy: 85.71%
# Epoch [105/500], Loss: 0.3294, Accuracy: 89.29%
# Epoch [106/500], Loss: 0.3505, Accuracy: 85.71%
# Epoch [107/500], Loss: 0.3297, Accuracy: 85.71%
# Epoch [108/500], Loss: 0.3342, Accuracy: 85.71%
# Epoch [109/500], Loss: 0.3414, Accuracy: 85.71%
# Epoch [110/500], Loss: 0.3507, Accuracy: 85.71%
# Epoch [111/500], Loss: 0.3398, Accuracy: 85.71%
# Epoch [112/500], Loss: 0.3317, Accuracy: 85.71%
# Epoch [113/500], Loss: 0.3262, Accuracy: 85.71%
# Epoch [114/500], Loss: 0.3185, Accuracy: 85.71%
# Epoch [115/500], Loss: 0.3466, Accuracy: 85.71%
# Epoch [116/500], Loss: 0.3199, Accuracy: 85.71%
# Epoch [117/500], Loss: 0.3268, Accuracy: 85.71%
# Epoch [118/500], Loss: 0.3329, Accuracy: 85.71%
# Epoch [119/500], Loss: 0.3418, Accuracy: 85.71%
# Epoch [120/500], Loss: 0.3365, Accuracy: 85.71%
# Epoch [121/500], Loss: 0.3276, Accuracy: 85.71%
# Epoch [122/500], Loss: 0.3217, Accuracy: 85.71%
# Epoch [123/500], Loss: 0.3139, Accuracy: 85.71%
# Epoch [124/500], Loss: 0.3077, Accuracy: 89.29%
# Epoch [125/500], Loss: 0.3299, Accuracy: 85.71%
# Epoch [126/500], Loss: 0.3172, Accuracy: 85.71%
# Epoch [127/500], Loss: 0.3323, Accuracy: 85.71%
# Epoch [128/500], Loss: 0.3626, Accuracy: 85.71%
# Epoch [129/500], Loss: 0.3673, Accuracy: 82.14%
# Epoch [130/500], Loss: 0.3474, Accuracy: 85.71%
# Epoch [131/500], Loss: 0.3219, Accuracy: 85.71%
# Epoch [132/500], Loss: 0.3110, Accuracy: 85.71%
# Epoch [133/500], Loss: 0.2981, Accuracy: 89.29%
# Epoch [134/500], Loss: 0.3750, Accuracy: 85.71%
# Epoch [135/500], Loss: 0.3501, Accuracy: 82.14%
# Epoch [136/500], Loss: 0.3062, Accuracy: 85.71%
# Epoch [137/500], Loss: 0.3201, Accuracy: 85.71%
# Epoch [138/500], Loss: 0.3459, Accuracy: 85.71%
# Epoch [139/500], Loss: 0.3578, Accuracy: 82.14%
# Epoch [140/500], Loss: 0.3513, Accuracy: 85.71%
# Epoch [141/500], Loss: 0.3315, Accuracy: 85.71%
# Epoch [142/500], Loss: 0.3103, Accuracy: 85.71%
# Epoch [143/500], Loss: 0.2963, Accuracy: 85.71%
# Epoch [144/500], Loss: 0.2675, Accuracy: 89.29%
# Epoch [145/500], Loss: 0.2735, Accuracy: 89.29%
# Epoch [146/500], Loss: 0.2925, Accuracy: 85.71%
# Epoch [147/500], Loss: 0.3029, Accuracy: 85.71%
# Epoch [148/500], Loss: 0.3114, Accuracy: 85.71%
# Epoch [149/500], Loss: 0.3164, Accuracy: 85.71%
# Epoch [150/500], Loss: 0.3131, Accuracy: 85.71%
# Epoch [151/500], Loss: 0.3042, Accuracy: 85.71%
# Epoch [152/500], Loss: 0.2950, Accuracy: 85.71%
# Epoch [153/500], Loss: 0.2785, Accuracy: 89.29%
# Epoch [154/500], Loss: 0.3131, Accuracy: 92.86%
# Epoch [155/500], Loss: 0.2473, Accuracy: 92.86%
# Epoch [156/500], Loss: 0.2852, Accuracy: 85.71%
# Epoch [157/500], Loss: 0.2917, Accuracy: 85.71%
# Epoch [158/500], Loss: 0.2937, Accuracy: 85.71%
# Epoch [159/500], Loss: 0.2923, Accuracy: 85.71%
# Epoch [160/500], Loss: 0.2870, Accuracy: 85.71%
# Epoch [161/500], Loss: 0.2622, Accuracy: 92.86%
# Epoch [162/500], Loss: 0.3490, Accuracy: 85.71%
# Epoch [163/500], Loss: 0.2402, Accuracy: 92.86%
# Epoch [164/500], Loss: 0.2841, Accuracy: 85.71%

# %%
dataloader = DataLoader(gait_dataset_train, batch_size=28, shuffle=False)

for X_val, y_val in dataloader: 
    print(X_val.shape)
X_val.requires_grad = True  # Enable gradient tracking for the inputs
outputs = model(X_val)
loss = criterion(outputs.squeeze(), y_val.float())
loss.backward()

# Compute average absolute gradient for each feature
feature_gradients = X_val.grad.abs().mean(dim=(0, 1))  # Average over batch and time dimensions
important_features = torch.argsort(feature_gradients, descending=True).tolist()
print("Feature Importance (from most to least):")
for num in important_features:
    if num in int2feat_all:
        feature_name = int2feat_all[num]
        gradient_value = feature_gradients[num].item()
        print(f"{feature_name}: Gradient = {gradient_value:.6f}")
# Out:
# torch.Size([28, 600, 14])
# Feature Importance (from most to least):
# flash_seconds: Gradient = 0.000098
# frac_band: Gradient = 0.000078
# time_sincelast: Gradient = 0.000068
# ampl: Gradient = 0.000063
# BandwidthesHz: Gradient = 0.000051
# phase: Gradient = 0.000044
# flash_periods: Gradient = 0.000035
# freq: Gradient = 0.000035
# right: Gradient = 0.000032
# Psi0: Gradient = 0.000026
# timeSigal: Gradient = 0.000026
# left: Gradient = 0.000021
# Bottom: Gradient = 0.000021
# top: Gradient = 0.000012

# %%
## Code to Verify Feature Normalization:

# Assuming X_val is the tensor of your features
# X_val has the shape (batch_size, sequence_length, num_features)

# Calculate mean and standard deviation for each feature
feature_means = X_val.mean(dim=(0, 1))  # Mean across batch and time dimensions
feature_stds = X_val.std(dim=(0, 1))    # Standard deviation across batch and time dimensions

# Print results for inspection
for i, (mean, std) in enumerate(zip(feature_means.tolist(), feature_stds.tolist())):
    print(f"Feature {i} - Mean: {mean:.5f}, Std: {std:.5f}")

# Check if features are approximately normalized (mean ~ 0, std ~ 1)
is_normalized = all(abs(mean) < 1e-5 and abs(std - 1) < 1e-2 for mean, std in zip(feature_means, feature_stds))
if is_normalized:
    print("Features are correctly normalized!")
else:
    print("Features are not properly normalized. Consider applying normalization.")
# Out:
# Feature 0 - Mean: 0.00710, Std: 0.03873
# Feature 1 - Mean: 0.17115, Std: 0.11410
# Feature 2 - Mean: 0.45620, Std: 0.26271
# Feature 3 - Mean: 0.07186, Std: 0.04765
# Feature 4 - Mean: 0.02657, Std: 0.05333
# Feature 5 - Mean: 0.18118, Std: 0.06836
# Feature 6 - Mean: 0.47709, Std: 0.27572
# Feature 7 - Mean: 0.49914, Std: 0.27072
# Feature 8 - Mean: 0.50178, Std: 0.28947
# Feature 9 - Mean: 0.48615, Std: 0.28136
# Feature 10 - Mean: 0.10275, Std: 0.08264
# Features are not properly normalized. Consider applying normalization.

# %%
# check for code for normalization
# Reshape to combine patients and time for normalization
print(all_train.shape)
reshaped_features = all_train.permute(1, 0, 2).reshape(num_feat, -1)  # after permutation, all_train.permute(1, 0, 2) changes the shape to (11, N_train, 600). Now, the features are in the first dimension, followed by the number of patients and the time dimension.

# Min-max normalization across features
min_values = reshaped_features.min(dim=1, keepdim=True).values  # Shape: (num_feat, 1)
max_values = reshaped_features.max(dim=1, keepdim=True).values  # Shape: (num_feat, 1)


# # Normalize
normalized_features_train = (reshaped_features - min_values) / (max_values - min_values + 1e-8)  # Avoid division by zero
print(normalized_features_train.shape)

# # Reshape back to the original structure (patients, features, time)
normalized_features_train = reshaped_features.reshape(num_feat, len(train_indices)*2,  600)
normalized_features_train  = normalized_features_train .permute(1, 0, 2)

print(normalized_features_train.shape)
# Check if two tensors are nearly equal
are_equal = torch.allclose(all_train, normalized_features_train, atol=1e-6)
# Print result
if are_equal:
    print("The two tensors are nearly equal.")
else:
    print("The two tensors are not equal.")

# # Split the normalized features into PDL and ETL datasets
# PDL_train = normalized_features_train[:len(train_indices), :, :]
# ETL_train = normalized_features_train[len(train_indices):, :, :]

# # Check the normalized shape
# print("Normalized train shape:", normalized_features_train.shape)
# Out:
# torch.Size([28, 11, 600])
# torch.Size([11, 16800])
# torch.Size([28, 11, 600])
# The two tensors are nearly equal.
