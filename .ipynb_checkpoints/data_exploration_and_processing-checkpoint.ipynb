# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from utils.data_loader import PatientsRawData

# %%
data = PatientsRawData('../data/Исходные файлы/')
data.load_data()

# %% [markdown]
# # Data loading

# %%
# display different information about the data
print(f' Data labels: {data.Y} for the total of {len(data.X)} data samples coming from patients: {data.patient}')
print('Explore a random data sample: ')
N = random.randint(0,len(data.X))
data.X[N].head()
# Out:
#  Data labels: ['Control', 'Control', 'Control', 'Control', 'Control', 'Control', 'Control', 'Control', 'ET', 'ET', 'ET', 'ET', 'ET', 'ET', 'ET', 'ET', 'ET', 'ET', 'ET', 'ET', 'ET', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Left', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right'] for the total of 41 data samples coming from patients: ['аста0101.txt', 'дюки0102.txt', 'керш0103.txt', 'лега0104.txt', 'сидо0105.txt', 'фрол0106.txt', 'хвал0107.txt', 'черк0108.txt', 'даке0101.txt', 'ершо0102.txt', 'кудр0103.txt', 'купр0104.txt', 'куту0105.txt', 'лити0106.txt', 'луче0107.txt', 'макс0108.txt', 'миро0109.txt', 'молю01010.txt', 'муха01011.txt', 'соко01012.txt', 'тихо01013.txt', 'ерми0101.txt', 'кова0102.txt', 'колг0103.txt', 'медв0104.txt', 'наза0105.txt', 'погр0106.txt', 'савв0107.txt', 'сави0108.txt', 'шелу0109.txt', 'бело0101.txt', 'гава0102.txt', 'голу0103.txt', 'грек0104.txt', 'губа0105.txt', 'павл0106.txt', 'пана0107.
# ...

# %% [markdown]
# # Data filtering and processing
# ## Display a sample of EMG Data

# %%
# let's now clean the data to only have EMG data
data.get_emg_data()
data.X[N].head()
# Out:
#    EMG1  EMG2  EMG3  EMG4
# 0   -53    -4   -18    31
# 1     9    -2    24     5
# 2     2    -2    22   -89
# 3    -2    -1    12   -39
# 4    35    -6     1    72

# %%
# let's display the original data (first 100  values)
data.X[N][:100].plot(figsize=(20, 10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Processing of the EMG data

# %% [markdown]
# ### Notch filter
# A notch filter is a band-stop filter with a narrow bandwidth (high quality factor). It rejects a narrow frequency band and leaves the rest of the spectrum little changed.
# Here the implementation from [scipy](https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.iirnotch.html) is used

# %%
from scipy.signal import iirnotch
from scipy import signal

# %%
# parameters for filters
frequences_to_filter = [50, 100, 150, 200 ] # frequence of 'setevaya navodka'
SamplingRate  = 500
LF= 60
UF= 240
#HalfRate= SamplingRate / 2 # Найквист fr
#W1= LF / HalfRate # stop frequency/nyq
#W2= UF / HalfRate # corner frequency/nyq
#HalfOrder= 4

# %%
def notch_filtering(Frequency,SelectedVector,SamplingRate,Q=35):
    '''remove Frequency from signal'''
    wo= Frequency / (SamplingRate / 2)
    # bw= wo / Q
    # Make order 2 bandstop digital filter
    b, a = signal.iirnotch(wo, Q) 
    notch_filtered=signal.lfilter(b, a, SelectedVector)
    return notch_filtered

# %% [markdown]
# ###  Butterworth filter
# Again taken from [scipy](https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.butter.html).
# Кроме того, для ЭМГ использовался фильтр Баттерворта с полосой пропускания от 60 до 240 Гц. Для АКС использовался фильтр Баттерворта с полосой пропускания от 0,1 до 240 Гц для анализа тремора в диапазоне частот от 0,5 до 4 Гц и с полосой пропускания от 2 до 240 Гц для анализа тремора в диапазоне частот от 4 до 50 Гц.

# %%
# Plot the frequency response for a few different orders.
# https://stackoverflow.com/questions/12093594/how-to-implement-band-pass-butterworth-filter-with-scipy-signal-butter

from scipy.signal import butter, lfilter

def butter_bandpass(lowcut, highcut, fs, order=5):
    return butter(order, [lowcut, highcut], fs=fs, btype='band')

def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y =signal.filtfilt(b, a, data)
    return y


# Sample rate and desired cutoff frequencies (in Hz).
fs = SamplingRate
lowcut = 60
highcut = 240

# Plot the frequency response for a few different orders.
plt.figure(1)
plt.clf()
for order in [1, 3, 6, 9]:
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    w, h = signal.freqz(b, a, fs=fs, worN=2000)
    plt.plot(w, abs(h), label="order = %d" % order)

    plt.plot([0, 0.5 * fs], [np.sqrt(0.5), np.sqrt(0.5)],
             '--', label='sqrt(0.5)')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Gain')
    plt.grid(True)
    plt.legend(loc='best')
plt.show()

# %%
# order selection
N, Wn = signal.buttord(60, 240,3, 40, False)
print(N)
# Out:
# 4

# %%
# Take one EMG signal to process
signal_emg = data.X[N]['EMG1'].to_numpy()

# %%
signal_emg[:100]
# Out:
# array([  0,   1,   0,   1,   1,   1,   2,  -4,   1,  11,  -6,   5,  -1,
#         -3,  15,   3,   0,   1,   2,   2,   3,   0,  -1,   1,   0,  -2,
#         -1,   0,   4,  -3,  -2,   7,  -6,  -1,   3,  13,  -6,   1,   1,
#          3,   3,   4,   0,   0,  -1,   0,   0,  -2,  -2,  -1,  -3,   3,
#          2,  -3,   0,   0,   0,   1,   0,   8,  -3,  -2,   0,   0,   4,
#         -7,   2,   2,  -1,  -3,   0,  -1,   5,  -1,   0,   0,   1,  -1,
#          0,   4,   0,  -2,   1,  -2,   3,  -1,   0,   1,  -1,   0,  -1,
#          0,  -1,   2,  -1,  -7,  -4,  28, -13,  -4])

# %%
# detrending of a signal
signal_emg_detrended = signal.detrend(signal_emg)

# %%
# plot spectrogram of the unprocessed signal
plt.figure(2)
plt.clf()
plt.magnitude_spectrum(signal_emg, Fs=SamplingRate)
plt.yscale('log')
plt.title('Magnitude of the signal, fs=500')
plt.axis('tight')

plt.magnitude_spectrum(signal_emg_detrended, Fs=SamplingRate)
plt.grid(True)
plt.yscale('log')
plt.title('Magnitude of the detrended signal, fs=500')
plt.axis('tight')
plt.legend(loc='upper left')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Notch filter only, applu
notch_filtered = signal_emg_detrended.copy()
for filtered_frequency in frequences_to_filter:
    notch_filtered = notch_filtering(filtered_frequency,notch_filtered,SamplingRate,Q=35)

# %%
plt.magnitude_spectrum(notch_filtered, Fs=SamplingRate)
plt.title(f'Magnitude  of Signal with Removed frequences {frequences_to_filter}')
plt.show()

# %%
# plot initial signal
t = np.arange(0, len(signal_emg)) /  SamplingRate
plt.figure(2)
plt.clf()
plt.plot(t, signal_emg, label='Noisy signal')
plt.axis('tight')

plt.plot(t, notch_filtered, label='Notch Filtered signal')
plt.grid(True)
plt.axis('tight')
plt.legend(loc='upper left')
plt.show()

# %%
# butterworth filter only
# Filter a noisy signal.
t = np.arange(0, len(signal_emg)) /  SamplingRate
plt.figure(2)
plt.clf()
plt.plot(t, signal_emg, label='Noisy signal')
plt.axis('tight')

y = butter_bandpass_filter(signal_emg, lowcut, highcut, fs, order=4)
plt.plot(t, y, label='Filtered signal')
plt.grid(True)
plt.axis('tight')
plt.legend(loc='upper left')
plt.show()

# %%
plt.figure(2)
plt.clf()
plt.magnitude_spectrum(signal_emg, Fs=SamplingRate, label='Noisy signal magnitude')
plt.axis('tight')

plt.magnitude_spectrum(y, Fs=SamplingRate, label=f'Magniture of the Signal with Removed frequences outside of 60-240')
plt.grid(True)
plt.axis('tight')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Finally, plot the signal which was first notch-filtered and then gone through the butterworth filter

# %%
# apply band filter on filtered signal
processed = butter_bandpass_filter(notch_filtered, lowcut, highcut, fs, order=4)

# %% [markdown]
# ### Display the final results
# Show the final sinal, and its spectrogram

# %%
# final signal after processing
t = np.arange(0, len(signal_emg)) /  SamplingRate
plt.figure(2)
plt.clf()
plt.plot(t, signal_emg, label='Noisy signal')
plt.axis('tight')

plt.plot(t,processed, label='Filtered final signal')
plt.grid(True)
plt.axis('tight')
plt.legend(loc='upper left')
plt.show()

# %%
# final spectr after processing
plt.figure(2)
plt.clf()
plt.magnitude_spectrum(signal_emg, Fs=SamplingRate, label='Noisy signal magnitude')
plt.axis('tight')

plt.magnitude_spectrum(processed, Fs=SamplingRate, label='Filtered final signal magnitude')
plt.grid(True)
plt.axis('tight')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# Visually, it looks like the newly processed signal is correct.
# Conirmed by Olga and Alexey, from their instructions the detrending was added.

# %% [markdown]
# ## Apply Hilbet function on the signal
#  Теперь можете вычислять огибающую. Обратите внимание, что для этого в Матлабе используется функция hilbert, но эта функция не просто вычисляет мнимый компонент для сигнала (что и должно делать преобразование Гильберта), а создает комплексный сигнал, включающий действительную и мнимую части. Наверняка, в Питоне должен быть аналог этой функции. А уже потом, по комплексному сигналу, можно вычислить мгновенную амплитуду (функцией abs) или мгновенную фазу (функцией angle).

# %%
processed_H = signal.hilbert(processed)
amplitude_envelope = np.abs(processed_H)

# %%
# final signal after processing
plt.figure(2)
plt.clf()
plt.plot(processed[:100], label='Filtered final signal')
plt.axis('tight')

plt.plot(amplitude_envelope[:100], label='Hilbert')
plt.grid(True)
plt.axis('tight')
plt.legend(loc='upper left')
plt.show()

# %%
amplitude_envelope[:100]
# Out:
# array([ 2.73781235,  1.79413115,  1.34634937,  0.68680264,  0.6812395 ,
#         0.64390741,  1.23764888,  4.78817087,  8.44697937,  9.6808556 ,
#         7.48690843,  4.36850211,  7.19670644, 10.37153137,  9.83206052,
#         6.46022079,  3.38226409,  2.02227579,  0.86064405,  3.01309312,
#         4.15483366,  3.52612828,  2.76123581,  2.45174124,  1.97200153,
#         1.95568513,  1.17136209,  2.06754182,  5.0355893 ,  6.61010334,
#         6.64296224,  6.01205567,  4.00130509,  2.6791584 ,  7.32188686,
#        10.03335016,  8.35090203,  3.50406507,  1.88983654,  3.84738983,
#         2.75414911,  0.52929974,  1.28440249,  1.23690231,  1.94706185,
#         3.33642363,  3.67038977,  2.68761882,  0.96669174,  0.85306659,
#         1.85292142,  2.8040833 ,  3.80269357,  3.53454132,  1.44006153,
#         1.52492539,  2.90349642,  2.32054133,  3.79740854,  6.35997282,
#         6.52129971,  3.92965822,  1.51775741,  3.89340891,  5.44910555,
# ...

# %% [markdown]
# # Data plots and exploration of the results

# %% [markdown]
# To explore the data, let's plot it to see the specifics of each signal.

# %%
from utils.preprocessing import preprocess_signal
import seaborn as sns
# %matplotlib notebook

# %%
# convert data to numpy and pre=process all the data
min_sequence = 10000000000
try:
    data.convert_to_numpy()
except:
    print('already converted, skipping!')
#preprocess all the data
for i in range(len(data.X)):
    one_patient_emg = data.X[i]
    for j, emg_channel in enumerate(one_patient_emg):
        if len(emg_channel)<min_sequence:
            min_sequence = len(emg_channel) 
        processed_signal =  preprocess_signal(emg_channel,  SamplingRate=500,  LF=60, HF=240, frequences_to_filter = [50, 100, 150, 200 ], order_butter=4, save_plot=False) 
        data.X[i][j]=processed_signal # save to the previous unprocessed signal
    print(f'Pre-processed patient {i}')

# %%
data.X[0][0,:]
data.Y[35]
# Out:
# 'Right'

# %%
# %matplotlib inline 
fig = plt.figure(figsize=(12, 4))
plt.plot(data.X[0][0,:])
plt.plot(data.X[0][1,:])
plt.plot(data.X[0][2,:])
plt.plot(data.X[0][3,:])
plt.title('Control patient, EMG1, EMG2, EMG3, EMG4')
# Out:
# Text(0.5, 1.0, 'Control patient, EMG1, EMG2, EMG3, EMG4')

# %%
# pair-wise plots for different patients: control patient vs tremor

# %%
figure, axis = plt.subplots(2, 2, figsize=(15, 15))


axis[0, 0].plot(data.X[0][0,:], label="Control", color="b")
axis[0, 0].plot(data.X[10][0,:], label="ET",color="r", alpha=0.6)
axis[0, 0].set_title(f"EMG1 Control {data.patient[0]}/ ET {data.patient[10]}")
  
axis[0, 1].plot(data.X[0][1,:],label="Control",color="b")
axis[0, 1].plot(data.X[10][1,:], label="ET",color="r",alpha=0.6)
axis[0, 1].set_title(f"EMG2 Control {data.patient[0]}/ ET {data.patient[10]}")
  
axis[1, 0].plot(data.X[0][2,:], label="Control",color="b")
axis[1, 0].plot(data.X[10][2,:], label="ET",color="r",alpha=0.6)
axis[1, 0].set_title(f"EMG3 Control {data.patient[0]}/ ET {data.patient[10]}")
  
axis[1, 1].plot(data.X[0][3,:],label="Control",color="b")
axis[1, 1].plot(data.X[10][3,:], label="ET",color="r",alpha=0.6)
axis[1, 1].set_title(f"EMG4 Control {data.patient[0]}/ ET {data.patient[10]}")

figure.legend(loc="upper left")
# Combine all the operations and display
plt.show()

# %%
figure, axis = plt.subplots(2, 2, figsize=(15, 15))


axis[0, 0].plot(data.X[1][0,:], label="Control", color="b")
axis[0, 0].plot(data.X[10][0,:], label="ET",color="r", alpha=0.6)
axis[0, 0].set_title(f"EMG1 Control {data.patient[1]}/ ET {data.patient[10]}")
  
axis[0, 1].plot(data.X[1][1,:],label="Control",color="b")
axis[0, 1].plot(data.X[10][1,:], label="ET",color="r",alpha=0.6)
axis[0, 1].set_title(f"EMG2 Control {data.patient[1]}/ ET {data.patient[10]}")
  
axis[1, 0].plot(data.X[1][2,:], label="Control",color="b")
axis[1, 0].plot(data.X[10][2,:], label="ET",color="r",alpha=0.6)
axis[1, 0].set_title(f"EMG3 Control {data.patient[1]}/ ET {data.patient[10]}")
  
axis[1, 1].plot(data.X[1][3,:],label="Control",color="b")
axis[1, 1].plot(data.X[10][3,:], label="ET",color="r",alpha=0.6)
axis[1, 1].set_title(f"EMG4 Control {data.patient[1]}/ ET {data.patient[10]}")

figure.legend(loc="upper left")
# Combine all the operations and display
plt.show()

# %%
## Parkinson Left and Right

# %%
figure, axis = plt.subplots(2, 2, figsize=(15, 15))


axis[0, 0].plot(data.X[22][0,:], label="Left", color="g")
axis[0, 0].plot(data.X[35][0,:], label="Right",color="m", alpha=0.6)
axis[0, 0].set_title(f"EMG1 Left {data.patient[22]}/ Right {data.patient[35]}")
  
axis[0, 1].plot(data.X[22][1,:],label="Left",color="g")
axis[0, 1].plot(data.X[35][1,:], label="Right",color="m",alpha=0.6)
axis[0, 1].set_title(f"EMG2 Left {data.patient[22]}/ Right {data.patient[35]}")
  
axis[1, 0].plot(data.X[22][2,:], label="Left",color="g")
axis[1, 0].plot(data.X[35][2,:], label="Right",color="m",alpha=0.6)
axis[1, 0].set_title(f"EMG3 Left {data.patient[22]}/ Right {data.patient[35]}")
  
axis[1, 1].plot(data.X[22][3,:],label="Left",color="g")
axis[1, 1].plot(data.X[35][3,:], label="Right",color="m",alpha=0.6)
axis[1, 1].set_title(f"EMG4 Left {data.patient[22]}/ Right {data.patient[35]}")

figure.legend(loc="upper left")
# Combine all the operations and display
